# %%
import pandas as pd
import numpy as np
import os

# %%
# Define the file path
FOLDER_PATH = "Dataset_test"
file_path = os.path.join(FOLDER_PATH, "dataset-final.csv")

# Load the CSV file into a DataFrame
df_final = pd.read_csv(file_path)

# %%
df_final
# Out:
#           Trader                                              Title Topic  \
# 0    AlanSantana         🅱️ Ethereum Will Hit Bottom Before Bitcoin   BTC
# 1    AlanSantana         🅱️ Ethereum Will Hit Bottom Before Bitcoin   BTC
# 2    AlanSantana  🅱️ Expert Confirms: Bitcoin Set To Crash Below...   BTC
# 3    AlanSantana  🅱️ Expert Confirms: Bitcoin Set To Crash Below...   BTC
# 4    AlanSantana  🅱️ Expert Confirms: Bitcoin Set To Crash Below...   BTC
# ..           ...                                                ...   ...
# 627       Xanrox       Bitcoin - new ATH soon. Best time to buy now   BTC
# 628       Xanrox       Bitcoin - new ATH soon. Best time to buy now   BTC
# 629       Xanrox  Bitcoin - Ultimate bottom will be here, but no...   BTC
# 630       Xanrox  Bitcoin - Ultimate bottom will be here, but no...   BTC
# 631       Xanrox        Bitcoin is ready to reach 70k! Here is why.   BTC
#
#      Post length      Post type   Timestamp     Price  \
# 0              2   Initial post  1715250618  61030.01
# 1              2  Update post 1  1718150706  67367.99
# 2              5   Initial post  1715767526  62465.74
# 3              5  Update post 1  1715869218  65918.09
# 4              5  Update post 2  1717238906  67654.74
# ..           ...            ...         ...       ...
# 627            8  Update post 5  1715923856  65483.40
# 628            8  Update post 7  1716020763  67023.76
# 629            2   Initial post  1715676697  61853.19
# 630            2  Update post 1  1715755990  61922.00
# 631            1   Initial post  1715328292  63010.01
#
#                                                   Text  Word count  \
# 0    I would like to call your attention to Bitcoin...         155
# 1    Comment:\nLower high on the monthly timeframe....          13
# 2    Signals are available everywhere... And new da...         355
# 3    Comment:\n🅱️ Time To Trade\n\nRight now we are...         530
# 4    Comment:\n🍀 AFFIRMATIONS TO ATTRACT ABUNDANCE\...         259
# ..                                                 ...         ...
# 627  Comment:\nBitcoin is pumping, thanks for readi...           9
# 628  Comment:\nPrice perfectly respected the parall...          15
# 629  The price action of Bitcoin is relatively bori...         281
# 630  Comment:\nOn the 1h chart, Bitcoin is forming ...          19
# 631  Bitcoin has finished its corrective pattern (A...         247
#
#      Stop words count  Stop word %  \
# 0                  59        38.06
# 1                   4        30.77
# 2                 163        45.92
# 3                 274        51.70
# 4                 122        47.10
# ..                ...          ...
# 627                 3        33.33
# 628                 3        20.00
# 629               134        47.69
# 630                 7        36.84
# 631               115        46.56
#
#                                             Lemmatized  Lemmatized_Count
# 0    The price at the moment is: 61030.01. would li...                 3
# 1    The price at the moment is: 67367.99. lower hi...                 0
# 2    The price at the moment is: 62465.74. signal a...                15
# 3    The price at the moment is: 65918.09. time tra...                18
# 4    The price at the moment is: 67654.74. affirmat...                14
# ..                                                 ...               ...
# 627  The price at the moment is: 65483.4. bitcoin p...                 0
# 628  The price at the moment is: 67023.76. price pe...                 1
# 629  The price at the moment is: 61853.19. price ac...                13
# 630  The price at the moment is: 61922.0. 1h chart ...                 1
# 631  The price at the moment is: 63010.01. bitcoin ...                 4
#
# [632 rows x 13 columns]

# %%
from textblob import TextBlob as tb
# Polarity means the sentiment of the text (in range of -1 to 1)
df_final["Polarity"] = df_final["Lemmatized"].apply(lambda x: tb(x).sentiment[0])
df_final["Polarity"]
# Out:
# 0     -0.005841
# 1      0.160000
# 2      0.137759
# 3      0.112534
# 4      0.485248
#          ...
# 627    0.000000
# 628    0.337500
# 629    0.140561
# 630    0.000000
# 631    0.126389
# Name: Polarity, Length: 632, dtype: float64

# %%
# subjectivity means the degree to which the text is subjective (in range of 0 to 1)
df_final["Subjectivity"] = df_final["Lemmatized"].apply(lambda x: tb(x).sentiment[1])
df_final["Subjectivity"]
# Out:
# 0      0.400930
# 1      0.540000
# 2      0.487588
# 3      0.460599
# 4      0.583437
#          ...
# 627    0.000000
# 628    0.475000
# 629    0.458418
# 630    0.000000
# 631    0.406250
# Name: Subjectivity, Length: 632, dtype: float64

# %%
df_final
# Out:
#           Trader                                              Title Topic  \
# 0    AlanSantana         🅱️ Ethereum Will Hit Bottom Before Bitcoin   BTC
# 1    AlanSantana         🅱️ Ethereum Will Hit Bottom Before Bitcoin   BTC
# 2    AlanSantana  🅱️ Expert Confirms: Bitcoin Set To Crash Below...   BTC
# 3    AlanSantana  🅱️ Expert Confirms: Bitcoin Set To Crash Below...   BTC
# 4    AlanSantana  🅱️ Expert Confirms: Bitcoin Set To Crash Below...   BTC
# ..           ...                                                ...   ...
# 627       Xanrox       Bitcoin - new ATH soon. Best time to buy now   BTC
# 628       Xanrox       Bitcoin - new ATH soon. Best time to buy now   BTC
# 629       Xanrox  Bitcoin - Ultimate bottom will be here, but no...   BTC
# 630       Xanrox  Bitcoin - Ultimate bottom will be here, but no...   BTC
# 631       Xanrox        Bitcoin is ready to reach 70k! Here is why.   BTC
#
#      Post length      Post type   Timestamp     Price  \
# 0              2   Initial post  1715250618  61030.01
# 1              2  Update post 1  1718150706  67367.99
# 2              5   Initial post  1715767526  62465.74
# 3              5  Update post 1  1715869218  65918.09
# 4              5  Update post 2  1717238906  67654.74
# ..           ...            ...         ...       ...
# 627            8  Update post 5  1715923856  65483.40
# 628            8  Update post 7  1716020763  67023.76
# 629            2   Initial post  1715676697  61853.19
# 630            2  Update post 1  1715755990  61922.00
# 631            1   Initial post  1715328292  63010.01
#
#                                                   Text  Word count  \
# 0    I would like to call your attention to Bitcoin...         155
# 1    Comment:\nLower high on the monthly timeframe....          13
# 2    Signals are available everywhere... And new da...         355
# 3    Comment:\n🅱️ Time To Trade\n\nRight now we are...         530
# 4    Comment:\n🍀 AFFIRMATIONS TO ATTRACT ABUNDANCE\...         259
# ..                                                 ...         ...
# 627  Comment:\nBitcoin is pumping, thanks for readi...           9
# 628  Comment:\nPrice perfectly respected the parall...          15
# 629  The price action of Bitcoin is relatively bori...         281
# 630  Comment:\nOn the 1h chart, Bitcoin is forming ...          19
# 631  Bitcoin has finished its corrective pattern (A...         247
#
#      Stop words count  Stop word %  \
# 0                  59        38.06
# 1                   4        30.77
# 2                 163        45.92
# 3                 274        51.70
# 4                 122        47.10
# ..                ...          ...
# 627                 3        33.33
# 628                 3        20.00
# 629               134        47.69
# 630                 7        36.84
# 631               115        46.56
#
#                                             Lemmatized  Lemmatized_Count  \
# 0    The price at the moment is: 61030.01. would li...                 3
# 1    The price at the moment is: 67367.99. lower hi...                 0
# 2    The price at the moment is: 62465.74. signal a...                15
# 3    The price at the moment is: 65918.09. time tra...                18
# 4    The price at the moment is: 67654.74. affirmat...                14
# ..                                                 ...               ...
# 627  The price at the moment is: 65483.4. bitcoin p...                 0
# 628  The price at the moment is: 67023.76. price pe...                 1
# 629  The price at the moment is: 61853.19. price ac...                13
# 630  The price at the moment is: 61922.0. 1h chart ...                 1
# 631  The price at the moment is: 63010.01. bitcoin ...                 4
#
#      Polarity  Subjectivity
# 0   -0.005841      0.400930
# 1    0.160000      0.540000
# 2    0.137759      0.487588
# 3    0.112534      0.460599
# 4    0.485248      0.583437
# ..        ...           ...
# 627  0.000000      0.000000
# 628  0.337500      0.475000
# 629  0.140561      0.458418
# 630  0.000000      0.000000
# 631  0.126389      0.406250
#
# [632 rows x 15 columns]

# %%
eth_df = df_final[df_final['Topic'] == 'SOL']
eth_df.sort_values(by="Timestamp")
# Out:
#             Trader                                        Title Topic  \
# 55     AlanSantana  ✴️ Solana 4X SHORT (222% Profits Potential)   SOL
# 56     AlanSantana  ✴️ Solana 4X SHORT (222% Profits Potential)   SOL
# 236  MoralDisciple                     Solana analysis BULLISH!   SOL
# 237  MoralDisciple                     Solana analysis BULLISH!   SOL
# 238  MoralDisciple                     Solana analysis BULLISH!   SOL
# 239  MoralDisciple                     Solana analysis BULLISH!   SOL
# 240  MoralDisciple                     Solana analysis BULLISH!   SOL
# 241  MoralDisciple                     Solana analysis BULLISH!   SOL
# 242  MoralDisciple                     Solana analysis BULLISH!   SOL
# 243  MoralDisciple                     Solana analysis BULLISH!   SOL
# 57     AlanSantana  ✴️ Solana 4X SHORT (222% Profits Potential)   SOL
#
#      Post length      Post type   Timestamp   Price  \
# 55             3   Initial post  1715406628  145.14
# 56             3  Update post 1  1715877419  157.93
# 236            8   Initial post  1716448214  176.98
# 237            8  Update post 1  1716449831  177.53
# 238            8  Update post 2  1716656609  167.40
# 239            8  Update post 3  1716657318  167.39
# 240            8  Update post 4  1716657419  167.38
# 241            8  Update post 5  1716716039  163.28
# 242            8  Update post 6  1717180932  165.80
# 243            8  Update post 7  1718038731  162.00
# 57             3  Update post 2  1718150037  149.42
#
#                                                   Text  Word count  \
# 55   Solana peaked March 2024, together with Bitcoi...         188
# 56   Comment:\nNotice how the reversal is happening...          10
# 236  Everything is pumping and the main thing is st...          15
# 237  Comment:\nAll altcoins give BS at the same tim...          23
# 238  Comment:\nAltcoins have BS today, today we see...          60
# 239  Comment:\nI remember when I entered many coins...          74
# 240  Comment:\nWe need to expand our investments mo...          11
# 241  Comment:\nThe Four Phases of an #Altcoin Bull ...         233
# 242  Comment:\nI'm still waiting for the BS to cool...          23
# 243  Comment:\nBitcoin is just getting started and ...          15
# 57   Comment:\nNothing changes, we continue advocat...          21
#
#      Stop words count  Stop word %  \
# 55                 69        36.70
# 56                  4        40.00
# 236                 6        40.00
# 237                13        56.52
# 238                29        48.33
# 239                40        54.05
# 240                 5        45.45
# 241                93        39.91
# 242                10        43.48
# 243                 8        53.33
# 57                  8        38.10
#
#                                             Lemmatized  Lemmatized_Count  \
# 55   The price at the moment is: 145.14. solana pea...                 8
# 56   The price at the moment is: 157.93. notice rev...                 0
# 236  The price at the moment is: 176.98. everything...                 0
# 237  The price at the moment is: 177.53. altcoins g...                 1
# 238  The price at the moment is: 167.4. altcoins b ...                 4
# 239  The price at the moment is: 167.39. remember e...                 2
# 240  The price at the moment is: 167.38. need expan...                 2
# 241  The price at the moment is: 163.28. four phase...                20
# 242  The price at the moment is: 165.8. still waiti...                 2
# 243  The price at the moment is: 162.0. bitcoin get...                 0
# 57   The price at the moment is: 149.42. nothing ch...                 1
#
#      Polarity  Subjectivity  Decision
# 55   0.185000      0.402566  Positive
# 56   0.285714      0.535714  Positive
# 236  0.233333      0.166667  Positive
# 237  0.285714      0.535714  Positive
# 238  0.187500      0.474537  Positive
# 239  0.430000      0.570000  Positive
# 240  0.000000      0.000000  Negative
# 241 -0.007574      0.415814  Negative
# 242  0.087500      0.537500  Positive
# 243  0.000000      0.000000  Negative
# 57   0.050000      0.400000  Positive

# %%
import networkx as nx
import matplotlib.pyplot as plt

# Add a column to determine buy/sell decision based on polarity
df_final['Decision'] = df_final['Polarity'].apply(lambda x: 'Positive' if x > 0 else 'Negative')

# Filter for the topic "Solana"
solana_df = df_final[df_final['Topic'] == 'SOL']

# %%
if not solana_df.empty:
    # Function to create and visualize graph for Solana topic
    def create_solana_graph(topic_df):
        G = nx.DiGraph()
        
        # Add the decision node
        decision_node = 'Decision'
        G.add_node(decision_node, label=decision_node, layer=0)
        
        # Add the topic node
        topic_node = 'Solana'
        G.add_node(topic_node, label=topic_node, layer=1)
        G.add_edge(decision_node, topic_node)
        
        # Sort posts by timestamp
        topic_df = topic_df.sort_values(by='Timestamp')
        
        # Dictionary to keep track of the last post for each title
        last_post_label = {}
        
        for _, row in topic_df.iterrows():
            post_label = f"Post_{row['Timestamp']}"
            title = row['Title']
            post_type = row['Post type']
            
            if post_type == 'Initial post':
                # Initial post node
                G.add_node(post_label, label=title, layer=2)
                G.add_edge(topic_node, post_label)
                last_post_label[title] = post_label
            else:
                # Update post node
                G.add_node(post_label, label=title, layer=3)
                if title in last_post_label:
                    initial_post_label = last_post_label[title]
                    G.add_edge(initial_post_label, post_label)
                else:
                    G.add_edge(topic_node, post_label)
        
        # Define the positions of nodes for visualization
        pos = nx.multipartite_layout(G, subset_key="layer")
        
        # Draw the graph
        plt.figure(figsize=(12, 8))
        nx.draw(G, pos, with_labels=True, labels=nx.get_node_attributes(G, 'label'), node_size=3000, node_color="skyblue", font_size=10, font_color="black", font_weight="bold")
        plt.title('Decision and Post Relationship Graph for Solana')
        plt.show()
    
    # Create and visualize graph for Solana topic
    create_solana_graph(solana_df)
else:
    print("No posts for the topic 'Solana'.")

# %%
if not solana_df.empty:
    # Function to create and visualize graph for Solana topic
    def create_solana_graph(topic_df):
        G = nx.DiGraph()
        
        # Add the decision node
        decision_node = 'Decision'
        G.add_node(decision_node, label=decision_node, layer=0)
        
        # Add the topic node
        topic_node = 'Solana'
        G.add_node(topic_node, label=topic_node, layer=1)
        G.add_edge(decision_node, topic_node)
        
        # Sort posts by timestamp
        topic_df = topic_df.sort_values(by='Timestamp')
        
        # Dictionary to keep track of the last post for each title
        last_post_label = {}
        
        for _, row in topic_df.iterrows():
            post_label = f"Post_{row['Timestamp']}"
            title = row['Title']
            post_type = row['Post type']
            
            # Add post node
            G.add_node(post_label, label=post_label, layer=2 if post_type == 'Initial post' else 3)
            
            if post_type == 'Initial post':
                # Connect initial post to the topic
                G.add_edge(topic_node, post_label)
                last_post_label[title] = post_label
            else:
                # Connect update posts to the last post of the same title
                if title in last_post_label:
                    last_post = last_post_label[title]
                    G.add_edge(last_post, post_label)
                    last_post_label[title] = post_label
                else:
                    G.add_edge(topic_node, post_label)
                    last_post_label[title] = post_label
        
        # Define the positions of nodes for visualization
        pos = nx.multipartite_layout(G, subset_key="layer")
        
        # Draw the graph
        plt.figure(figsize=(12, 8))
        nx.draw(G, pos, with_labels=True, labels=nx.get_node_attributes(G, 'label'), node_size=3000, node_color="skyblue", font_size=10, font_color="black", font_weight="bold")
        plt.title('Decision and Post Relationship Graph for Solana')
        plt.show()
    
    # Create and visualize graph for Solana topic
    create_solana_graph(solana_df)
else:
    print("No posts for the topic 'Solana'.")

# %%
if not solana_df.empty:
    # Function to create and visualize graph for Solana topic
    def create_solana_graph(topic_df):
        G = nx.DiGraph()
        
        # Add the decision node
        decision_node = 'Decision'
        G.add_node(decision_node, label=decision_node, layer=0)
        
        # Add the topic node
        topic_node = 'Solana'
        G.add_node(topic_node, label=topic_node, layer=1)
        G.add_edge(decision_node, topic_node)
        
        # Sort posts by timestamp
        topic_df = topic_df.sort_values(by='Timestamp')
        
        # Dictionary to keep track of the last post for each title
        last_post_label = {}
        layer_counter = 2
        
        for _, row in topic_df.iterrows():
            post_label = f"Post_{row['Timestamp']}"
            title = row['Title']
            post_type = row['Post type']
            
            if post_type == 'Initial post':
                # Initial post node
                G.add_node(post_label, label=post_label, layer=layer_counter)
                G.add_edge(topic_node, post_label)
                last_post_label[title] = post_label
            else:
                # Update post node
                if title in last_post_label:
                    previous_post_label = last_post_label[title]
                    layer_counter += 1
                    G.add_node(post_label, label=post_label, layer=layer_counter)
                    G.add_edge(previous_post_label, post_label)
                    last_post_label[title] = post_label
        
        # Define the positions of nodes for visualization
        pos = nx.multipartite_layout(G, subset_key="layer", align="horizontal")
        
        # Draw the graph
        plt.figure(figsize=(16, 12))
        nx.draw(G, pos, with_labels=True, labels=nx.get_node_attributes(G, 'label'), node_size=3000, node_color="skyblue", font_size=10, font_color="black", font_weight="bold", arrows=True)
        plt.title('Decision and Post Relationship Graph for Solana')
        plt.show()
    
    # Create and visualize graph for Solana topic
    create_solana_graph(solana_df)
else:
    print("No posts for the topic 'Solana'.")

# %%
if not solana_df.empty:
    # Function to create and visualize graph for Solana topic
    def create_solana_graph(topic_df):
        G = nx.DiGraph()
        
        # Add the decision node
        decision_node = 'Decision'
        G.add_node(decision_node, label=decision_node, layer=0)
        
        # Add the topic node
        topic_node = 'Solana'
        G.add_node(topic_node, label=topic_node, layer=1)
        G.add_edge(topic_node, decision_node)
        
        # Sort posts by timestamp
        topic_df = topic_df.sort_values(by='Timestamp')
        
        # Dictionary to keep track of the last post for each title
        last_post_label = {}
        layer_counter = 2
        
        for _, row in topic_df.iterrows():
            post_label = f"Post_{row['Timestamp']}"
            title = row['Title']
            post_type = row['Post type']
            
            if post_type == 'Initial post':
                # Initial post node
                G.add_node(post_label, label=post_label, layer=layer_counter)
                G.add_edge(post_label, topic_node)
                last_post_label[title] = post_label
            else:
                # Update post node
                if title in last_post_label:
                    previous_post_label = last_post_label[title]
                    layer_counter += 1
                    G.add_node(post_label, label=post_label, layer=layer_counter)
                    G.add_edge(post_label, previous_post_label)
                    last_post_label[title] = post_label
        
        # Define the positions of nodes for visualization
        pos = nx.multipartite_layout(G, subset_key="layer", align="vertical")
        
        # Draw the graph
        plt.figure(figsize=(16, 12))
        nx.draw(G, pos, with_labels=True, labels=nx.get_node_attributes(G, 'label'), node_size=3000, node_color="skyblue", font_size=10, font_color="black", font_weight="bold", arrows=True)
        plt.title('Decision and Post Relationship Graph for Solana')
        plt.show()
    
    # Create and visualize graph for Solana topic
    create_solana_graph(solana_df)
else:
    print("No posts for the topic 'Solana'.")

# %%
if not solana_df.empty:
    # Define a function to generate a color map for traders
    def get_trader_colors(traders):
        unique_traders = list(set(traders))
        colors = plt.get_cmap('tab10', len(unique_traders))  # Get a colormap with enough colors
        trader_color_map = {trader: colors(i) for i, trader in enumerate(unique_traders)}
        return trader_color_map
    
    # Function to create and visualize graph for Solana topic
    def create_solana_graph(topic_df):
        G = nx.DiGraph()
        
        # Add the decision node
        decision_node = 'Decision'
        G.add_node(decision_node, label=decision_node, layer=0, color='gray')
        
        # Add the topic node
        topic_node = 'Solana'
        G.add_node(topic_node, label=topic_node, layer=1, color='gray')
        G.add_edge(topic_node, decision_node)
        
        # Sort posts by timestamp
        topic_df = topic_df.sort_values(by='Timestamp')
        
        # Dictionary to keep track of the last post for each title
        last_post_label = {}
        layer_counter = 2
        
        # Get the color map for traders
        trader_colors = get_trader_colors(topic_df['Trader'])
        
        for _, row in topic_df.iterrows():
            post_label = f"Post_{row['Timestamp']}"
            title = row['Title']
            trader = row['Trader']
            post_type = row['Post type']
            
            if post_type == 'Initial post':
                # Initial post node
                G.add_node(post_label, label=trader, layer=layer_counter, color=trader_colors[trader])
                G.add_edge(post_label, topic_node)
                last_post_label[title] = post_label
            else:
                # Update post node
                if title in last_post_label:
                    previous_post_label = last_post_label[title]
                    layer_counter += 1
                    G.add_node(post_label, label=trader, layer=layer_counter, color=trader_colors[trader])
                    G.add_edge(post_label, previous_post_label)
                    last_post_label[title] = post_label
        
        # Define the positions of nodes for visualization
        pos = nx.multipartite_layout(G, subset_key="layer", align="vertical")
        
        # Draw the graph
        plt.figure(figsize=(16, 12))
        
        # Extract node colors
        node_colors = [nx.get_node_attributes(G, 'color').get(node, 'gray') for node in G.nodes]
        
        nx.draw(G, pos, with_labels=True, labels=nx.get_node_attributes(G, 'label'), node_size=3000, node_color=node_colors, font_size=10, font_color="black", font_weight="bold", arrows=True)
        plt.title('Decision and Post Relationship Graph for Solana')
        plt.show()
    
    # Create and visualize graph for Solana topic
    create_solana_graph(solana_df)
else:
    print("No posts for the topic 'Solana'.")

# %%
if not solana_df.empty:
    # Define a function to generate a color map for traders
    def get_trader_colors(traders):
        unique_traders = list(set(traders))
        colors = plt.get_cmap('tab10', len(unique_traders))  # Get a colormap with enough colors
        trader_color_map = {trader: colors(i) for i, trader in enumerate(unique_traders)}
        return trader_color_map
    
    # Function to create and visualize graph for Solana topic
    def create_solana_graph(topic_df):
        G = nx.DiGraph()
        
        # Add the decision node
        decision_node = 'Decision'
        G.add_node(decision_node, label=decision_node, layer=0, color='gray', decision=None)
        
        # Add the topic node
        topic_node = 'Solana'
        G.add_node(topic_node, label=topic_node, layer=1, color='gray', decision=None)
        G.add_edge(topic_node, decision_node, color='black')
        
        # Sort posts by timestamp
        topic_df = topic_df.sort_values(by='Timestamp')
        
        # Dictionary to keep track of the last post for each title
        last_post_label = {}
        layer_counter = 2
        
        # Get the color map for traders
        trader_colors = get_trader_colors(topic_df['Trader'])
        
        for _, row in topic_df.iterrows():
            post_label = f"Post_{row['Timestamp']}"
            title = row['Title']
            trader = row['Trader']
            post_type = row['Post type']
            decision = row['Decision']
            
            if post_type == 'Initial post':
                # Initial post node
                G.add_node(post_label, label=trader, layer=layer_counter, color=trader_colors[trader], decision=decision)
                G.add_edge(post_label, topic_node, color='black')
                last_post_label[title] = post_label
            else:
                # Update post node
                if title in last_post_label:
                    previous_post_label = last_post_label[title]
                    layer_counter += 1
                    G.add_node(post_label, label=trader, layer=layer_counter, color=trader_colors[trader], decision=decision)
                    
                    # Determine edge color based on decision
                    previous_decision = G.nodes[previous_post_label]['decision']
                    edge_color = 'green' if previous_decision == decision else 'red'
                    
                    G.add_edge(post_label, previous_post_label, color=edge_color)
                    last_post_label[title] = post_label
        
        # Define the positions of nodes for visualization
        pos = nx.multipartite_layout(G, subset_key="layer", align="vertical")
        
        # Draw the graph
        plt.figure(figsize=(16, 12))
        
        # Extract node colors
        node_colors = [nx.get_node_attributes(G, 'color').get(node, 'gray') for node in G.nodes]
        edge_colors = [G[u][v]['color'] for u, v in G.edges]
        
        nx.draw(G, pos, with_labels=True, labels=nx.get_node_attributes(G, 'label'), node_size=3000, node_color=node_colors, font_size=10, font_color="black", font_weight="bold", edge_color=edge_colors, arrows=True)
        plt.title('Decision and Post Relationship Graph for Solana')
        plt.show()
    
    # Create and visualize graph for Solana topic
    create_solana_graph(solana_df)
else:
    print("No posts for the topic 'Solana'.")
